# %%
# Useful for debugging
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
#  # Xopt CNSGA algorithm

# %%
from xopt.generators.ga.cnsga import CNSGAGenerator

from xopt.resources.test_functions.tnk import evaluate_TNK, tnk_vocs

from xopt import Xopt, Evaluator

# %%
ev = Evaluator(function=evaluate_TNK)
ev.function_kwargs = {'raise_probability':0.1} # optional random crashing, to mimic real-world use.

# %%
X = Xopt(
    generator=CNSGAGenerator(tnk_vocs),
    evaluator=ev,
    vocs=tnk_vocs,
)

# %%
# %%time
# Run 100 generations
for _ in range(64 * 20):
    X.step()
# Out:
# CPU times: user 8.94 s, sys: 44.3 ms, total: 8.99 s
# Wall time: 8.98 s

# %% [markdown]
# # Plot

# %%
import matplotlib.pyplot as plt

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
fig, ax = plt.subplots(figsize=(8, 8))

fdata = tnk_vocs.feasibility_data(X.data)

k1 = "x1"
k2 = "x2"

X.data.plot.scatter(k1, k2, marker=".", alpha=0.1, color="black", ax=ax)
X.data[fdata["feasible"]].plot.scatter(
    k1, k2, marker="x", alpha=0.3, color="orange", ax=ax
)
X.generator.population.plot.scatter(k1, k2, marker="o", color="red", alpha=1, ax=ax)
ax.set_xlabel(k1)
ax.set_ylabel(k2)
ax.set_xlim(0, 1.5)
ax.set_ylim(0, 1.5)
ax.set_title("TNK with Xopt's CNSGA")
# Out:
# Text(0.5, 1.0, "TNK with Xopt's CNSGA")

# %%
# Write the current population
X.generator.write_population('test.csv')

# %% [markdown]
# # YAML method

# %%
from xopt import Xopt

# %%
YAML = """
xopt:
    max_evaluations: 6400
generator:
    name: cnsga
    population_size: 64
    population_file: test.csv
    output_path: .

evaluator:
    function: xopt.resources.test_functions.tnk.evaluate_TNK
    function_kwargs:
      raise_probability: 0.1

vocs:
    variables:
        x1: [0, 3.14159]
        x2: [0, 3.14159]
    objectives: {y1: MINIMIZE, y2: MINIMIZE}
    constraints:
        c1: [GREATER_THAN, 0]
        c2: [LESS_THAN, 0.5]
    linked_variables: {x9: x1}
    constants: {a: dummy_constant}

"""

X = Xopt(YAML)
X
# Out:
#             Xopt
# ________________________________
# Version: 0+untagged.1.g78a74e0
# Data size: 0
# Config as YAML:
# xopt: {asynch: false, strict: false, dump_file: null, max_evaluations: 6400}
# generator: {name: cnsga, population_size: 64, crossover_probability: 0.9, mutation_probability: 1.0,
#   population_file: test.csv, output_path: .}
# evaluator:
#   function: xopt.resources.test_functions.tnk.evaluate_TNK
#   max_workers: 1
#   function_kwargs: {sleep: 0, random_sleep: 0, raise_probability: 0.1}
# vocs:
#   variables:
#     x1: [0.0, 3.14159]
#     x2: [0.0, 3.14159]
#   constraints:
#     c1: [GREATER_THAN, 0.0]
#     c2: [LESS_THAN, 0.5]
#   objectives: {y1: MINIMIZE, y2: MINIMIZE}
#   constants: {a: dummy_constant}
#   linked_variables: {x9: x1}

# %%
# This will have loaded children from the population file. These will need to be re-evaluated.
len(X.generator.children)
# Out:
# 64

# %%
# %%time
X.run()
# Out:
# CPU times: user 49.2 s, sys: 88.1 ms, total: 49.3 s
# Wall time: 49.3 s

# %%
len(X.data)
# Out:
# 6400

# %%
# With output_path set, these are written
from glob import glob
pop_files = sorted(glob("cnsga_population*"))
pop_files
# Out:
# ['cnsga_population_2022-07-02T04:30:50.311819+00:00.csv',
#  'cnsga_population_2022-07-02T04:30:50.757295+00:00.csv',
#  'cnsga_population_2022-07-02T04:30:51.219094+00:00.csv',
#  'cnsga_population_2022-07-02T04:30:51.676809+00:00.csv',
#  'cnsga_population_2022-07-02T04:30:52.114027+00:00.csv',
#  'cnsga_population_2022-07-02T04:30:52.552335+00:00.csv',
#  'cnsga_population_2022-07-02T04:30:52.982560+00:00.csv',
#  'cnsga_population_2022-07-02T04:30:53.435321+00:00.csv',
#  'cnsga_population_2022-07-02T04:30:53.873636+00:00.csv',
#  'cnsga_population_2022-07-02T04:30:54.317462+00:00.csv',
#  'cnsga_population_2022-07-02T04:30:54.751084+00:00.csv',
#  'cnsga_population_2022-07-02T04:30:55.194854+00:00.csv',
#  'cnsga_population_2022-07-02T04:30:55.642425+00:00.csv',
#  'cnsga_population_2022-07-02T04:30:56.069974+00:00.csv',
#  'cnsga_population_2022-07-02T04:30:56.515028+00:00.csv',
#  'cnsga_population_2022-07-02T04:30:56.946698+00:00.csv',
#  'cnsga_population_2022-07-02T04:30:57.386802+00:00.csv',
#  'cnsga_population_2022-07-02T04:30:57.869004+00:00.csv',
#  'cnsga_population_2022-07-02T04:30:58.311265+00:00.csv',
#  'cnsga_population_2022-07-02T04:30:58.752412+00:00.csv',
#  'cnsga_population_2022-07-02T04:30:59.246159+00:00.csv',
#  'cnsga_population_2022-07-02T04:30:59.712750+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:00.216227+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:00.663965+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:01.121304+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:01.575204+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:02.036766+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:02.499285+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:02.961153+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:03.449559+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:03.943196+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:04.435905+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:04.933074+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:05.426541+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:05.928812+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:06.425199+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:06.926857+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:07.456930+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:07.953133+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:08.486809+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:08.990235+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:09.491512+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:09.994361+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:10.498688+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:11.005890+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:11.507650+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:12.042495+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:12.554555+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:13.063034+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:13.567742+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:14.079573+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:14.617683+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:15.127811+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:15.633746+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:16.143789+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:16.651120+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:17.160545+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:17.665206+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:18.173549+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:18.681157+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:19.188290+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:19.694564+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:20.235794+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:20.776877+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:21.286054+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:21.794977+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:22.305277+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:22.847180+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:23.356307+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:23.869298+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:24.381621+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:24.891085+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:25.404346+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:25.916889+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:26.463599+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:26.970649+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:27.483056+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:27.993776+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:28.509399+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:29.022674+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:29.533077+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:30.043743+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:30.556474+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:31.067283+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:31.578822+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:32.095080+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:32.607117+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:33.121535+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:33.665806+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:34.186180+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:34.702025+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:35.213684+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:35.714032+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:36.198327+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:36.693645+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:37.202531+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:37.681987+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:38.199395+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:38.687767+00:00.csv',
#  'cnsga_population_2022-07-02T04:31:39.184027+00:00.csv']

# %%
import pandas as pd
pop_df = pd.read_csv(pop_files[-1], index_col="xopt_index")

pop_df.plot.scatter("x1", "x2", marker="o", color="red", alpha=1)
# Out:
# <AxesSubplot:xlabel='x1', ylabel='x2'>

# %%
# Cleanup
# !rm cnsga_population*
# !rm test.csv
