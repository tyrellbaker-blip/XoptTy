# %%
# Useful for debugging
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
#  # Xopt CNSGA algorithm

# %%
from xopt.generators.ga.cnsga import CNSGAGenerator

from xopt.resources.test_functions.tnk import evaluate_TNK, tnk_vocs

from xopt import Xopt, Evaluator

# %%
ev = Evaluator(function=evaluate_TNK)
ev.function_kwargs = {'raise_probability':0.1} # optional random crashing, to mimic real-world use.

# %%
X = Xopt(
    generator=CNSGAGenerator(tnk_vocs),
    evaluator=ev,
    vocs=tnk_vocs,
)

# %%
# %%time
# Run 100 generations
for _ in range(64 * 20):
    X.step()
# Out:
# CPU times: user 7.71 s, sys: 7.91 ms, total: 7.71 s
# Wall time: 7.71 s

# %% [markdown]
# # Plot

# %%
import matplotlib.pyplot as plt

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
fig, ax = plt.subplots(figsize=(8, 8))

fdata = tnk_vocs.feasibility_data(X.data)

k1 = "x1"
k2 = "x2"

X.data.plot.scatter(k1, k2, marker=".", alpha=0.1, color="black", ax=ax)
X.data[fdata["feasible"]].plot.scatter(
    k1, k2, marker="x", alpha=0.3, color="orange", ax=ax
)
X.generator.population.plot.scatter(k1, k2, marker="o", color="red", alpha=1, ax=ax)
ax.set_xlabel(k1)
ax.set_ylabel(k2)
ax.set_xlim(0, 1.5)
ax.set_ylim(0, 1.5)
ax.set_title("TNK with Xopt's CNSGA")
# Out:
# Text(0.5, 1.0, "TNK with Xopt's CNSGA")

# %%
# Write the current population
X.generator.write_population('test.csv')

# %% [markdown]
# # YAML method

# %%
from xopt import Xopt

# %%
YAML = """
xopt:
    max_evaluations: 6400
generator:
    name: cnsga
    population_size: 64
    population_file: test.csv
    output_path: .

evaluator:
    function: xopt.resources.test_functions.tnk.evaluate_TNK
    function_kwargs:
      raise_probability: 0.1

vocs:
    variables:
        x1: [0, 3.14159]
        x2: [0, 3.14159]
    objectives: {y1: MINIMIZE, y2: MINIMIZE}
    constraints:
        c1: [GREATER_THAN, 0]
        c2: [LESS_THAN, 0.5]
    linked_variables: {x9: x1}
    constants: {a: dummy_constant}

"""

X = Xopt(YAML)
X
# Out:
#             Xopt
# ________________________________
# Version: 0+untagged.1.g6b21941
# Data size: 0
# Config as YAML:
# xopt: {asynch: false, strict: false, dump_file: null, max_evaluations: 6400}
# generator: {name: cnsga, population_size: 64, crossover_probability: 0.9, mutation_probability: 1.0,
#   population_file: test.csv, output_path: .}
# evaluator:
#   function: xopt.resources.test_functions.tnk.evaluate_TNK
#   max_workers: 1
#   function_kwargs: {sleep: 0, random_sleep: 0, raise_probability: 0.1}
# vocs:
#   variables:
#     x1: [0.0, 3.14159]
#     x2: [0.0, 3.14159]
#   constraints:
#     c1: [GREATER_THAN, 0.0]
#     c2: [LESS_THAN, 0.5]
#   objectives: {y1: MINIMIZE, y2: MINIMIZE}
#   constants: {a: dummy_constant}
#   linked_variables: {x9: x1}

# %%
# This will have loaded children from the population file. These will need to be re-evaluated.
len(X.generator.children)
# Out:
# 64

# %%
# %%time
X.run()
# Out:
# CPU times: user 44.5 s, sys: 55.6 ms, total: 44.5 s
# Wall time: 44.5 s

# %%
len(X.data)
# Out:
# 6400

# %%
# With output_path set, these are written
from glob import glob
pop_files = sorted(glob("cnsga_population*"))
pop_files
# Out:
# ['cnsga_population_2022-07-02T04:01:44.284344+00:00.csv',
#  'cnsga_population_2022-07-02T04:01:44.717689+00:00.csv',
#  'cnsga_population_2022-07-02T04:01:45.139760+00:00.csv',
#  'cnsga_population_2022-07-02T04:01:45.558276+00:00.csv',
#  'cnsga_population_2022-07-02T04:01:45.979257+00:00.csv',
#  'cnsga_population_2022-07-02T04:01:46.401133+00:00.csv',
#  'cnsga_population_2022-07-02T04:01:46.823925+00:00.csv',
#  'cnsga_population_2022-07-02T04:01:47.247103+00:00.csv',
#  'cnsga_population_2022-07-02T04:01:47.670993+00:00.csv',
#  'cnsga_population_2022-07-02T04:01:48.097725+00:00.csv',
#  'cnsga_population_2022-07-02T04:01:48.523709+00:00.csv',
#  'cnsga_population_2022-07-02T04:01:48.948664+00:00.csv',
#  'cnsga_population_2022-07-02T04:01:49.374114+00:00.csv',
#  'cnsga_population_2022-07-02T04:01:49.809047+00:00.csv',
#  'cnsga_population_2022-07-02T04:01:50.247818+00:00.csv',
#  'cnsga_population_2022-07-02T04:01:50.676859+00:00.csv',
#  'cnsga_population_2022-07-02T04:01:51.109196+00:00.csv',
#  'cnsga_population_2022-07-02T04:01:51.540422+00:00.csv',
#  'cnsga_population_2022-07-02T04:01:51.971730+00:00.csv',
#  'cnsga_population_2022-07-02T04:01:52.403721+00:00.csv',
#  'cnsga_population_2022-07-02T04:01:52.834098+00:00.csv',
#  'cnsga_population_2022-07-02T04:01:53.264603+00:00.csv',
#  'cnsga_population_2022-07-02T04:01:53.696594+00:00.csv',
#  'cnsga_population_2022-07-02T04:01:54.132389+00:00.csv',
#  'cnsga_population_2022-07-02T04:01:54.566548+00:00.csv',
#  'cnsga_population_2022-07-02T04:01:55.001134+00:00.csv',
#  'cnsga_population_2022-07-02T04:01:55.438630+00:00.csv',
#  'cnsga_population_2022-07-02T04:01:55.875438+00:00.csv',
#  'cnsga_population_2022-07-02T04:01:56.313372+00:00.csv',
#  'cnsga_population_2022-07-02T04:01:56.750824+00:00.csv',
#  'cnsga_population_2022-07-02T04:01:57.190714+00:00.csv',
#  'cnsga_population_2022-07-02T04:01:57.627005+00:00.csv',
#  'cnsga_population_2022-07-02T04:01:58.065248+00:00.csv',
#  'cnsga_population_2022-07-02T04:01:58.504795+00:00.csv',
#  'cnsga_population_2022-07-02T04:01:58.943934+00:00.csv',
#  'cnsga_population_2022-07-02T04:01:59.384197+00:00.csv',
#  'cnsga_population_2022-07-02T04:01:59.824786+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:00.263926+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:00.704853+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:01.146814+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:01.589076+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:02.031481+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:02.473201+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:02.916371+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:03.359928+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:03.808336+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:04.254477+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:04.703460+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:05.152494+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:05.599464+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:06.051034+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:06.500984+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:06.949683+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:07.399707+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:07.848521+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:08.299986+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:08.752131+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:09.204377+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:09.654618+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:10.106225+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:10.559546+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:11.011984+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:11.463335+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:11.914181+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:12.366439+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:12.817291+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:13.270250+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:13.721250+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:14.171842+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:14.625275+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:15.079466+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:15.534825+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:15.987755+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:16.441967+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:16.900664+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:17.356954+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:17.811532+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:18.266751+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:18.724484+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:19.181344+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:19.637321+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:20.098294+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:20.555382+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:21.013243+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:21.471109+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:21.928066+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:22.387084+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:22.846842+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:23.305706+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:23.767460+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:24.229260+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:24.692224+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:25.156799+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:25.624661+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:26.090103+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:26.553394+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:27.016988+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:27.483614+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:27.950045+00:00.csv',
#  'cnsga_population_2022-07-02T04:02:28.418756+00:00.csv']

# %%
import pandas as pd
pop_df = pd.read_csv(pop_files[-1], index_col="xopt_index")

pop_df.plot.scatter("x1", "x2", marker="o", color="red", alpha=1)
# Out:
# <AxesSubplot:xlabel='x1', ylabel='x2'>

# %%
# Cleanup
# !rm cnsga_population*
# !rm test.csv
