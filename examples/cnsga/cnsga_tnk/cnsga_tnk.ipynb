# %%
# Useful for debugging
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
#  # Xopt CNSGA algorithm

# %%
from xopt.generators.ga.cnsga import CNSGAGenerator

from xopt.resources.test_functions.tnk import evaluate_TNK, tnk_vocs

from xopt import Xopt, Evaluator

# %%
ev = Evaluator(function=evaluate_TNK)
ev.function_kwargs = {'raise_probability':0.1} # optional random crashing, to mimic real-world use.

# %%
X = Xopt(
    generator=CNSGAGenerator(tnk_vocs),
    evaluator=ev,
    vocs=tnk_vocs,
)

# %%
# %%time
# Run 100 generations
for _ in range(64 * 20):
    X.step()
# Out:
# CPU times: user 7.99 s, sys: 20.2 ms, total: 8.01 s
# Wall time: 7.99 s

# %% [markdown]
# # Plot

# %%
import matplotlib.pyplot as plt

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
fig, ax = plt.subplots(figsize=(8, 8))

fdata = tnk_vocs.feasibility_data(X.data)

k1 = "x1"
k2 = "x2"

X.data.plot.scatter(k1, k2, marker=".", alpha=0.1, color="black", ax=ax)
X.data[fdata["feasible"]].plot.scatter(
    k1, k2, marker="x", alpha=0.3, color="orange", ax=ax
)
X.generator.population.plot.scatter(k1, k2, marker="o", color="red", alpha=1, ax=ax)
ax.set_xlabel(k1)
ax.set_ylabel(k2)
ax.set_xlim(0, 1.5)
ax.set_ylim(0, 1.5)
ax.set_title("TNK with Xopt's CNSGA")
# Out:
# Text(0.5, 1.0, "TNK with Xopt's CNSGA")

# %%
# Write the current population
X.generator.write_population('test.csv')

# %% [markdown]
# # YAML method

# %%
from xopt import Xopt

# %%
YAML = """
xopt:
    max_evaluations: 6400
generator:
    name: cnsga
    population_size: 64
    population_file: test.csv
    output_path: .

evaluator:
    function: xopt.resources.test_functions.tnk.evaluate_TNK
    function_kwargs:
      raise_probability: 0.1

vocs:
    variables:
        x1: [0, 3.14159]
        x2: [0, 3.14159]
    objectives: {y1: MINIMIZE, y2: MINIMIZE}
    constraints:
        c1: [GREATER_THAN, 0]
        c2: [LESS_THAN, 0.5]
    linked_variables: {x9: x1}
    constants: {a: dummy_constant}

"""

X = Xopt(YAML)
X
# Out:
#             Xopt
# ________________________________
# Version: 0+untagged.1.g7b8e7ed
# Data size: 0
# Config as YAML:
# xopt: {asynch: false, strict: false, dump_file: null, max_evaluations: 6400}
# generator: {name: cnsga, population_size: 64, crossover_probability: 0.9, mutation_probability: 1.0,
#   population_file: test.csv, output_path: .}
# evaluator:
#   function: xopt.resources.test_functions.tnk.evaluate_TNK
#   max_workers: 1
#   function_kwargs: {sleep: 0, random_sleep: 0, raise_probability: 0.1}
# vocs:
#   variables:
#     x1: [0.0, 3.14159]
#     x2: [0.0, 3.14159]
#   constraints:
#     c1: [GREATER_THAN, 0.0]
#     c2: [LESS_THAN, 0.5]
#   objectives: {y1: MINIMIZE, y2: MINIMIZE}
#   constants: {a: dummy_constant}
#   linked_variables: {x9: x1}

# %%
# This will have loaded children from the population file. These will need to be re-evaluated.
len(X.generator.children)
# Out:
# 64

# %%
# %%time
X.run()
# Out:
# CPU times: user 41.9 s, sys: 55.8 ms, total: 41.9 s
# Wall time: 41.9 s

# %%
len(X.data)
# Out:
# 6400

# %%
# With output_path set, these are written
from glob import glob
pop_files = sorted(glob("cnsga_population*"))
pop_files
# Out:
# ['cnsga_population_2022-07-02T20:54:46.663883+00:00.csv',
#  'cnsga_population_2022-07-02T20:54:47.063408+00:00.csv',
#  'cnsga_population_2022-07-02T20:54:47.463962+00:00.csv',
#  'cnsga_population_2022-07-02T20:54:47.864375+00:00.csv',
#  'cnsga_population_2022-07-02T20:54:48.268054+00:00.csv',
#  'cnsga_population_2022-07-02T20:54:48.671223+00:00.csv',
#  'cnsga_population_2022-07-02T20:54:49.075801+00:00.csv',
#  'cnsga_population_2022-07-02T20:54:49.478963+00:00.csv',
#  'cnsga_population_2022-07-02T20:54:49.882194+00:00.csv',
#  'cnsga_population_2022-07-02T20:54:50.311617+00:00.csv',
#  'cnsga_population_2022-07-02T20:54:50.711962+00:00.csv',
#  'cnsga_population_2022-07-02T20:54:51.114039+00:00.csv',
#  'cnsga_population_2022-07-02T20:54:51.545281+00:00.csv',
#  'cnsga_population_2022-07-02T20:54:51.948346+00:00.csv',
#  'cnsga_population_2022-07-02T20:54:52.349280+00:00.csv',
#  'cnsga_population_2022-07-02T20:54:52.752867+00:00.csv',
#  'cnsga_population_2022-07-02T20:54:53.155116+00:00.csv',
#  'cnsga_population_2022-07-02T20:54:53.586172+00:00.csv',
#  'cnsga_population_2022-07-02T20:54:53.989728+00:00.csv',
#  'cnsga_population_2022-07-02T20:54:54.421098+00:00.csv',
#  'cnsga_population_2022-07-02T20:54:54.824464+00:00.csv',
#  'cnsga_population_2022-07-02T20:54:55.229299+00:00.csv',
#  'cnsga_population_2022-07-02T20:54:55.634382+00:00.csv',
#  'cnsga_population_2022-07-02T20:54:56.041465+00:00.csv',
#  'cnsga_population_2022-07-02T20:54:56.444636+00:00.csv',
#  'cnsga_population_2022-07-02T20:54:56.852252+00:00.csv',
#  'cnsga_population_2022-07-02T20:54:57.257960+00:00.csv',
#  'cnsga_population_2022-07-02T20:54:57.662709+00:00.csv',
#  'cnsga_population_2022-07-02T20:54:58.068059+00:00.csv',
#  'cnsga_population_2022-07-02T20:54:58.473666+00:00.csv',
#  'cnsga_population_2022-07-02T20:54:58.881467+00:00.csv',
#  'cnsga_population_2022-07-02T20:54:59.290292+00:00.csv',
#  'cnsga_population_2022-07-02T20:54:59.698092+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:00.106720+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:00.517930+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:00.926884+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:01.337584+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:01.748284+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:02.165106+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:02.577323+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:02.989011+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:03.428831+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:03.842791+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:04.254791+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:04.696583+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:05.111287+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:05.527714+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:05.942963+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:06.358365+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:06.774222+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:07.219655+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:07.636431+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:08.055442+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:08.474337+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:08.896153+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:09.318899+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:09.739920+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:10.159182+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:10.608142+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:11.031559+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:11.451247+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:11.873746+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:12.298811+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:12.722073+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:13.144318+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:13.565921+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:13.987797+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:14.409791+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:14.834451+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:15.258173+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:15.684771+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:16.107837+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:16.532362+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:16.958491+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:17.385263+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:17.810663+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:18.238666+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:18.666104+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:19.092488+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:19.521357+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:19.948815+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:20.378620+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:20.835306+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:21.263572+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:21.691561+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:22.121221+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:22.550326+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:22.981501+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:23.410113+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:23.850501+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:24.282670+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:24.715805+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:25.147310+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:25.580922+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:26.013088+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:26.444223+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:26.878389+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:27.310359+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:27.743754+00:00.csv',
#  'cnsga_population_2022-07-02T20:55:28.179140+00:00.csv']

# %%
import pandas as pd
pop_df = pd.read_csv(pop_files[-1], index_col="xopt_index")

pop_df.plot.scatter("x1", "x2", marker="o", color="red", alpha=1)
# Out:
# <AxesSubplot:xlabel='x1', ylabel='x2'>

# %%
# Cleanup
# !rm cnsga_population*
# !rm test.csv
