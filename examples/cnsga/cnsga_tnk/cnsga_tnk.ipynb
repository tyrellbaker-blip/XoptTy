# %%
# Useful for debugging
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
#  # Xopt CNSGA algorithm

# %%
from xopt.generators.ga.cnsga import CNSGAGenerator

from xopt.resources.test_functions.tnk import evaluate_TNK, tnk_vocs

from xopt import Xopt, Evaluator

# %%
ev = Evaluator(function=evaluate_TNK)
ev.function_kwargs = {'raise_probability':0.1} # optional random crashing, to mimic real-world use.

# %%
X = Xopt(
    generator=CNSGAGenerator(tnk_vocs),
    evaluator=ev,
    vocs=tnk_vocs,
)

# %%
# %%time
# Run 100 generations
for _ in range(64 * 20):
    X.step()
# Out:
# CPU times: user 8.19 s, sys: 15.6 ms, total: 8.21 s
# Wall time: 8.21 s

# %% [markdown]
# # Plot

# %%
import matplotlib.pyplot as plt

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
fig, ax = plt.subplots(figsize=(8, 8))

fdata = tnk_vocs.feasibility_data(X.data)

k1 = "x1"
k2 = "x2"

X.data.plot.scatter(k1, k2, marker=".", alpha=0.1, color="black", ax=ax)
X.data[fdata["feasible"]].plot.scatter(
    k1, k2, marker="x", alpha=0.3, color="orange", ax=ax
)
X.generator.population.plot.scatter(k1, k2, marker="o", color="red", alpha=1, ax=ax)
ax.set_xlabel(k1)
ax.set_ylabel(k2)
ax.set_xlim(0, 1.5)
ax.set_ylim(0, 1.5)
ax.set_title("TNK with Xopt's CNSGA")
# Out:
# Text(0.5, 1.0, "TNK with Xopt's CNSGA")

# %%
# Write the current population
X.generator.write_population('test.csv')

# %% [markdown]
# # YAML method

# %%
from xopt import Xopt

# %%
YAML = """
xopt:
    max_evaluations: 6400
generator:
    name: cnsga
    population_size: 64
    population_file: test.csv
    output_path: .

evaluator:
    function: xopt.resources.test_functions.tnk.evaluate_TNK
    function_kwargs:
      raise_probability: 0.1

vocs:
    variables:
        x1: [0, 3.14159]
        x2: [0, 3.14159]
    objectives: {y1: MINIMIZE, y2: MINIMIZE}
    constraints:
        c1: [GREATER_THAN, 0]
        c2: [LESS_THAN, 0.5]
    linked_variables: {x9: x1}
    constants: {a: dummy_constant}

"""

X = Xopt(YAML)
X
# Out:
#             Xopt
# ________________________________
# Version: 0+untagged.1.g99bb130
# Data size: 0
# Config as YAML:
# xopt: {asynch: false, strict: false, dump_file: null, max_evaluations: 6400}
# generator: {name: cnsga, population_size: 64, crossover_probability: 0.9, mutation_probability: 1.0,
#   population_file: test.csv, output_path: .}
# evaluator:
#   function: xopt.resources.test_functions.tnk.evaluate_TNK
#   max_workers: 1
#   function_kwargs: {sleep: 0, random_sleep: 0, raise_probability: 0.1}
# vocs:
#   variables:
#     x1: [0.0, 3.14159]
#     x2: [0.0, 3.14159]
#   constraints:
#     c1: [GREATER_THAN, 0.0]
#     c2: [LESS_THAN, 0.5]
#   objectives: {y1: MINIMIZE, y2: MINIMIZE}
#   constants: {a: dummy_constant}
#   linked_variables: {x9: x1}

# %%
# This will have loaded children from the population file. These will need to be re-evaluated.
len(X.generator.children)
# Out:
# 64

# %%
# %%time
X.run()
# Out:
# CPU times: user 47.2 s, sys: 51.9 ms, total: 47.3 s
# Wall time: 47.3 s

# %%
len(X.data)
# Out:
# 6400

# %%
# With output_path set, these are written
from glob import glob
pop_files = sorted(glob("cnsga_population*"))
pop_files
# Out:
# ['cnsga_population_2022-07-03T02:32:04.572544+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:05.022189+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:05.475880+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:05.931641+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:06.389717+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:06.847337+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:07.303905+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:07.761333+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:08.217172+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:08.672199+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:09.128060+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:09.584337+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:10.041567+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:10.502747+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:10.964305+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:11.425255+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:11.888767+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:12.348539+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:12.809530+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:13.271424+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:13.733928+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:14.196539+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:14.658219+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:15.120450+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:15.583825+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:16.046815+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:16.512077+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:16.978362+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:17.444287+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:17.909312+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:18.375126+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:18.839513+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:19.304204+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:19.769790+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:20.235701+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:20.703585+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:21.173320+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:21.643587+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:22.113371+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:22.582274+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:23.050278+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:23.519544+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:23.988134+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:24.456927+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:24.929073+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:25.399254+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:25.872843+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:26.345899+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:26.818392+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:27.291606+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:27.767733+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:28.242632+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:28.716830+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:29.192072+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:29.666668+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:30.141030+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:30.618443+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:31.095665+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:31.582356+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:32.058746+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:32.536687+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:33.014759+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:33.494697+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:33.972199+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:34.453014+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:34.933107+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:35.413073+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:35.895487+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:36.374230+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:36.853915+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:37.335758+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:37.816977+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:38.298068+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:38.783461+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:39.264384+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:39.746800+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:40.230294+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:40.713910+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:41.199821+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:41.684262+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:42.166876+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:42.649518+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:43.132924+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:43.617270+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:44.103178+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:44.588317+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:45.074427+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:45.566772+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:46.056833+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:46.543705+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:47.031761+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:47.519846+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:48.007570+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:48.498093+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:48.985434+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:49.473450+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:49.960265+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:50.452696+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:50.944808+00:00.csv',
#  'cnsga_population_2022-07-03T02:32:51.433758+00:00.csv']

# %%
import pandas as pd
pop_df = pd.read_csv(pop_files[-1], index_col="xopt_index")

pop_df.plot.scatter("x1", "x2", marker="o", color="red", alpha=1)
# Out:
# <AxesSubplot:xlabel='x1', ylabel='x2'>

# %%
# Cleanup
# !rm cnsga_population*
# !rm test.csv
